# %% [markdown]
# ## Part 1 LSTM

# %% [markdown]
# ### 1. Length 5

# %%
import argparse
import train
from lstm import LSTM

# %%
import matplotlib.pyplot as plt
def show_accu(x_axis1,y_axis1,y_axis2,x_label,y_label):
    # %matplotlib inline
    plt.plot(x_axis1,y_axis1,'g--')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    plt.plot(x_axis1,y_axis2,'b--')
    plt.xlabel(x_label)
    plt.ylabel("accuracy")

# %%
parser = argparse.ArgumentParser()

# Model params
parser.add_argument('--input_length', type=int, default=5, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=1000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis,loss_lst,accu_lst,model=train.train(config)
# Out:
#   0%|          | 0/128000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:43: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 128128it [17:01, 125.38it/s]
# Done training.

# %%
show_accu(x_axis,loss_lst,accu_lst,"sample","loss")

# %% [markdown]
# ### 2. Length 6

# %%
parser6 = argparse.ArgumentParser()

# Model params
parser6.add_argument('--input_length', type=int, default=6, help='Length of an input sequence') # 10
parser6.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser6.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser6.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser6.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser6.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser6.add_argument('--train_steps', type=int, default=600, help='Number of training steps') #10000
parser6.add_argument('--max_norm', type=float, default=10.0)

config6 = parser6.parse_args(args=[])
x_axis6,loss_lst6,accu_lst6,model6=train.train(config6)
# Out:
#   0%|          | 0/76800 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:43: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 76928it [06:03, 211.48it/s]
# Done training.

# %%
show_accu(x_axis6,loss_lst6,accu_lst6,"sample","loss")

# %% [markdown]
# ### 3. Length 7

# %%
parser7 = argparse.ArgumentParser()

# Model params
parser7.add_argument('--input_length', type=int, default=7, help='Length of an input sequence') # 10
parser7.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser7.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser7.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser7.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser7.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser7.add_argument('--train_steps', type=int, default=600, help='Number of training steps') #10000
parser7.add_argument('--max_norm', type=float, default=10.0)

config7 = parser7.parse_args(args=[])
x_axis7,loss_lst7,accu_lst7,model7=train.train(config7)
# Out:
#   0%|          | 0/76800 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:43: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 76928it [06:49, 188.09it/s]
# Done training.

# %%
show_accu(x_axis7,loss_lst7,accu_lst7,"sample","loss")

# %% [markdown]
# ### 4. Length 10

# %%
parser10 = argparse.ArgumentParser()

# Model params
parser10.add_argument('--input_length', type=int, default=10, help='Length of an input sequence') # 10
parser10.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser10.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser10.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser10.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser10.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser10.add_argument('--train_steps', type=int, default=600, help='Number of training steps') #10000
parser10.add_argument('--max_norm', type=float, default=10.0)

config10 = parser10.parse_args(args=[])
x_axis10,loss_lst10,accu_lst10,model10=train.train(config10)
# Out:
# 76928it [09:30, 134.93it/s]
# Done training.

# %%
show_accu(x_axis10,loss_lst10,accu_lst10,"sample","loss")

# %% [markdown]
# ### 5. Length 15

# %%
parser15 = argparse.ArgumentParser()

# Model params
parser15.add_argument('--input_length', type=int, default=15, help='Length of an input sequence') # 10
parser15.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser15.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser15.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser15.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser15.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser15.add_argument('--train_steps', type=int, default=1000, help='Number of training steps') #10000
parser15.add_argument('--max_norm', type=float, default=10.0)

config15 = parser15.parse_args(args=[])
x_axis15,loss_lst15,accu_lst15,model15=train.train(config15)

# %%
show_accu(x_axis15,loss_lst15,accu_lst15,"sample","loss")

# %% [markdown]
# ### 6. Length 18

# %%
parser18 = argparse.ArgumentParser()

# Model params
parser18.add_argument('--input_length', type=int, default=18, help='Length of an input sequence') # 10
parser18.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser18.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser18.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser18.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser18.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser18.add_argument('--train_steps', type=int, default=1000, help='Number of training steps') #10000
parser18.add_argument('--max_norm', type=float, default=10.0)

config18 = parser18.parse_args(args=[])
x_axis18,loss_lst18,accu_lst18,model18=train.train(config18)
# Out:
#   0%|          | 0/128000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:43: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 128128it [31:18, 68.22it/s]
# Done training.

# %%
show_accu(x_axis18,loss_lst18,accu_lst18,"sample","loss")

# %% [markdown]
# ### 7. Length 20

# %%
parser20 = argparse.ArgumentParser()

# Model params
parser20.add_argument('--input_length', type=int, default=20, help='Length of an input sequence') # 10
parser20.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser20.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser20.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser20.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser20.add_argument('--learning_rate', type=float, default=0.01, help='Learning rate')
parser20.add_argument('--train_steps', type=int, default=1600, help='Number of training steps') #10000
parser20.add_argument('--max_*norm', type=float, default=10.0)

config20 = parser20.parse_args(args=[])
x_axis20,loss_lst20,accu_lst20,model20=train.train(config20)

# %%
show_accu(x_axis20,loss_lst20,accu_lst20,"sample","loss")

# %% [markdown]
# ### 8. Length 20 with lr scheduler

# %%
parser20_1 = argparse.ArgumentParser()

# Model params
parser20_1.add_argument('--input_length', type=int, default=20, help='Length of an input sequence') # 10
parser20_1.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser20_1.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser20_1.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser20_1.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser20_1.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser20_1.add_argument('--train_steps', type=int, default=500, help='Number of training steps') #10000
parser20_1.add_argument('--max_norm', type=float, default=10.0)

config20_1 = parser20_1.parse_args(args=[])
model20_1 = LSTM(seq_length=config20_1.input_length,input_dim=config20_1.input_dim,hidden_dim=config20_1.num_hidden,output_dim=config20_1.num_classes,
                 batch_size=config20_1.batch_size)
x_axis20_1,loss_lst20_1,accu_lst20_1,model20_1=train.train_with_model(config20_1,model20_1)
# Out:
#   0%|          | 0/64000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:86: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 64128it [15:38, 68.30it/s]
# Done training.

# %%
show_accu(x_axis20_1,loss_lst20_1,accu_lst20_1,"sample","loss")
