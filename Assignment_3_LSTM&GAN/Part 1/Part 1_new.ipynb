# %% [markdown]
# ### Part 1

# %% [markdown]
# #### Task 1:
# Detailed implementation of LSTM and training process is in `lstm.py` and `train.py`
# #### Task 2:
# Experiment the performance of LSTM with different input length from 5 to 45<br>
# The following figures indicates the stronger performance of LSTM comparing to vanilla RNN
# from the last assignment.

# %%
# %matplotlib inline
# %run train.py --input_length 5
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [00:20, 9546.03it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 10
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [00:31, 6167.02it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 15
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [00:41, 4599.55it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 20
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [00:52, 3628.94it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 25
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [01:03, 3033.00it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 30
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [01:14, 2576.89it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 35
# Out:
#   0%|          | 0/192000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 192128it [01:25, 2238.01it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 40 --train_steps 3000
# Out:
#   0%|          | 0/384000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 384128it [03:11, 2010.62it/s]
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 45 --train_steps 4000
# Out:
#   0%|          | 0/512000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_3_LSTM&GAN\Part 1\train.py:58: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# 512128it [04:55, 1735.84it/s]
# Done training.

# %% [markdown]
# #### RNN's cannot achieve perfect performance after the input length increases to 10

# %%
import matplotlib.pyplot as plt
from PIL import Image
img1 = Image.open('vanilla.png')
plt.axis('off')
plt.imshow(img1)
plt.show()
