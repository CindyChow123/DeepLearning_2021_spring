# %% [markdown]
# # Assignment 2
# ## Part3: PyTorch RNN
# ### Task1: Vanilla RNN implementation
# #### Please refer to vanilla_rnn.py and train.py
# ### Task2: Display the inability for one-layer RNN to explain long sequences
# #### 1. Setting the max epoch time to 10000 with input length 5.
# We can see the vanilla rnn model can achieve nearly a perfect accuracy before the first 2000 batch epochs with 128*2000 input samples.

# %%
from vanilla_rnn import VanillaRNN
import train
import argparse
parser = argparse.ArgumentParser()

# Model params
parser.add_argument('--input_length', type=int, default=5, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=10000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis,loss_lst,accu_lst=train.train(config)
# Out:
# model training::   0%|          | 0/1280000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 1280128it [29:19, 727.66it/s]
# Done training.

# %%
import matplotlib.pyplot as plt
def show_accu(x_axis1,y_axis1,y_axis2,x_label,y_label):
    # %matplotlib inline
    plt.plot(x_axis1,y_axis1,'g--')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    plt.plot(x_axis1,y_axis2,'b--')
    plt.xlabel(x_label)
    plt.ylabel("accuracy")

# %%
show_accu(x_axis,loss_lst,accu_lst,"sample","loss")

# %% [markdown]
# #### 2. Setting the max epoch to 1000 with input length 5.
# Just for more careful observations of the nearly perfect performance at around 1000 epoch.

# %%
from vanilla_rnn import VanillaRNN
import train
import argparse
parser = argparse.ArgumentParser()

# Model params
parser.add_argument('--input_length', type=int, default=5, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=1000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis2,loss_lst2,accu_lst2=train.train(config)
# Out:
# model training::   0%|          | 0/128000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 128128it [03:08, 680.89it/s]
# Done training.

# %%
show_accu(x_axis2,loss_lst2,accu_lst2,"sample","loss")

# %% [markdown]
# #### 3. Setting the max epoch to 10000 with input length 8
# The accuracy is around 0.1.

# %%
from vanilla_rnn import VanillaRNN
import train
import argparse
parser = argparse.ArgumentParser()

# Model params
parser.add_argument('--input_length', type=int, default=8, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=10000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis3,loss_lst3,accu_lst3=train.train(config)
# Out:
# model training::   0%|          | 0/1280000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 1280128it [49:02, 435.08it/s]
# Done training.

# %%
show_accu(x_axis3,loss_lst3,accu_lst3,"sample","loss")

# %% [markdown]
# #### 4. Setting the max epoch to 2000 with input length 9.
# According to previous experiments, we reduce the number of epoches to 2000. The accuracy is around 0.2.

# %%
import train
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--input_length', type=int, default=9, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=2000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis5,loss_lst5,accu_lst5=train.train(config)
# Out:
# model training::   0%|          | 0/256000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 256128it [10:57, 389.77it/s]
# Done training.

# %%
show_accu(x_axis5,loss_lst5,accu_lst5,"sample","loss")

# %% [markdown]
# #### 5. Setting the max epoch to 2000 with input length 10.
# The accuracy is around 0.12.

# %%
import train
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--input_length', type=int, default=10, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=2000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis6,loss_lst6,accu_lst6=train.train(config)
# Out:
# model training::   0%|          | 0/256000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 256128it [11:32, 369.97it/s]
# Done training.

# %%
show_accu(x_axis6,loss_lst6,accu_lst6,"sample","loss")

# %% [markdown]
# #### 6. Setting the max epoch to 10000 with input length 6.
# RNN can achieve nearly perfect performance in this setting.

# %%
import train
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--input_length', type=int, default=6, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=10000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis4,loss_lst4,accu_lst4=train.train(config)
# Out:
# model training::   0%|          | 0/1280000 [00:00<?, ?it/s]C:\Users\IT\PycharmProjects\deepLearning\Assignment_2_CNN&RNN\Part 3\train.py:41: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# model training:: : 1280128it [35:16, 604.81it/s]
# Done training.

# %%
show_accu(x_axis4,loss_lst4,accu_lst4,"sample","loss")

# %% [markdown]
# ### 7. Experiments using input length less than 5
# #### Setting the max epoch to 10000 with input length 4.

# %%
import train
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('--input_length', type=int, default=4, help='Length of an input sequence') # 10
parser.add_argument('--input_dim', type=int, default=1, help='Dimensionality of input sequence')
parser.add_argument('--num_classes', type=int, default=10, help='Dimensionality of output sequence')# 10
parser.add_argument('--num_hidden', type=int, default=128, help='Number of hidden units in the model')
parser.add_argument('--batch_size', type=int, default=128, help='Number of examples to process in a batch')
parser.add_argument('--learning_rate', type=float, default=0.001, help='Learning rate')
parser.add_argument('--train_steps', type=int, default=10000, help='Number of training steps') #10000
parser.add_argument('--max_norm', type=float, default=10.0)

config = parser.parse_args(args=[])
x_axis7,loss_lst7,accu_lst7=train.train(config)
# Out:
# model training:: : 1280128it [24:48, 860.10it/s]
# Done training.

# %%
show_accu(x_axis7,loss_lst7,accu_lst7,"sample","loss")

# %% [markdown]
# ### Analysis
# The curve shows the accuracy versus palindrome length using tha max accuracy of each input length
# experiment

# %%
import matplotlib.pyplot as plt
score=[0,0,0,0,0,0]
x=[4,5,6,8,9,10]
score[0]=max(accu_lst7)
score[1]=max(accu_lst)
score[2]=max(accu_lst4)
score[3]=max(accu_lst3)
score[4]=max(accu_lst5)
score[5]=max(accu_lst6)
plt.plot(x,score,'g--')
plt.xlabel("input sequence length")
plt.ylabel("max accuracy")
# Out:
# Text(0, 0.5, 'max accuracy')
